# %%
import pandas as pd

# def load_jsonl_to_csv(jsonl_file):
#     # Read the JSONL file into a DataFrame
#     df = pd.read_json(jsonl_file, lines=True)

#     # # Convert the DataFrame to CSV
#     # df.to_csv("output.csv", index=False)

#     # print("successfully converted to CSV and saved")

# # Call the function with your JSONL file name
# load_jsonl_to_csv("Grocery_and_Gourmet_Food.jsonl")

# %%
import pandas as pd
# read text file into pandas DataFrame
df = pd.read_csv("item_output.txt", sep=",")
# display DataFrame
print(df)
# Out:
#        main_category                                              title
# 0            Grocery                             Dark Roast Pure Coffee  \
# 1            Grocery  PICARAS Galletas Peruanas Bañadas en Chocolate...
# 2            Grocery  Chipped Beef and Gravy By Patterson's - Great ...
# 3            Grocery  Asher's Sugar Free Milk Chocolate Cordial Cher...
# 4            Grocery              Messmer Peppermint 25 bags (6er pack)
# ...              ...                                                ...
# 540008       Grocery  LVEUD Happy Birthday Cake Topper Black Font Go...
# 540009       Grocery  Sugar Free Hard Candy Factor Zero Espresso Cof...
# 540010       Grocery  Tre Mulini: "Mezze Penne Rigate" Durum Wheat S...
# 540011       Grocery  KaBloom PRIME NEXT DAY DELIVERY - 12 Fresh Pur...
# 540012       Grocery  Drapers Super Bee Tulip Poplar Honey in Glass ...
#
#         average_rating  rating_number
# 0                  4.7              9  \
# ...

# %%
df.head()
# Out:
#   main_category                                              title
# 0       Grocery                             Dark Roast Pure Coffee  \
# 1       Grocery  PICARAS Galletas Peruanas Bañadas en Chocolate...
# 2       Grocery  Chipped Beef and Gravy By Patterson's - Great ...
# 3       Grocery  Asher's Sugar Free Milk Chocolate Cordial Cher...
# 4       Grocery              Messmer Peppermint 25 bags (6er pack)
#
#    average_rating  rating_number
# 0             4.7              9  \
# 1             4.5             12
# 2             3.2              5
# 3             5.0              6
# 4             3.5              5
#
#                                             features
# 0                                                 []  \
# 1  ['2 Bags of PICARAS Galletas Bañadas en Chocol...
# 2  ['Six (6) 8-ounce cans of delicious chipped be...
# 3                                                 []
# 4                                                 []
#
# ...

# %%
product_data = df.copy()

# %%
import pandas as pd
# read text file into pandas DataFrame
df1 = pd.read_csv("output2.txt", sep=",")
# display DataFrame
print(df1)
# Out:
#         rating                                              title
# 0            5                                 Excellent!  Yummy!  \
# 1            5                                  Delicious!!! Yum!
# 2            5             Extremely Delicious, but expensive imo
# 3            5                                         Delicious!
# 4            5                                        Great taste
# ...        ...                                                ...
# 199996       2                       Tastes good but it's the MSG
# 199997       2  The chicken is good by itself but this should ...
# 199998       2  Ok but not that good and not a good after tast...
# 199999       2  It's weird. I would rather have a bowl of caul...
# 200000       2                                  Not a good flavor
#
#                                                      text        asin
# 0       Excellent!! Yummy!  Great with other foods and...  B00CM36GAQ  \
# ...

# %%
reviews_data = df1.copy()
reviews_data.head()
# Out:
#    rating                                   title
# 0       5                      Excellent!  Yummy!  \
# 1       5                       Delicious!!! Yum!
# 2       5  Extremely Delicious, but expensive imo
# 3       5                              Delicious!
# 4       5                             Great taste
#
#                                                 text        asin parent_asin
# 0  Excellent!! Yummy!  Great with other foods and...  B00CM36GAQ  B00CM36GAQ  \
# 1  Excellent!  The best!  I use it with my beef a...  B074J5WVYH  B0759B7KLH
# 2  These are very tasty. They are extremely soft ...  B079TRNVHX  B079TRNVHX
# 3                                       My favorite!  B07194LN2Z  B07194LN2Z
# 4     Great for making brownies and crinkle cookies.  B005CD4196  B005CD4196
#
#                         user_id      timestamp  helpful_vote
# 0  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1587854482395             0  \
# 1  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1587854400380             0
# ...

# %%
nan_count = product_data['price'].isna().sum()
total_count = len(product_data['price'])
print(f"NaN count in 'MyColumn': {nan_count} out of {total_count} total values")
# Out:
# NaN count in 'MyColumn': 341230 out of 540013 total values

# %%
variance = product_data['price'].var()
print(variance)
# Out:
# 1338.4712942048852
